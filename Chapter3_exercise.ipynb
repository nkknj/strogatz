# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
pi=np.pi
inf=np.inf

# %%
#3.1 サドルノード分岐
#3.1.1 ベクトル場は省略し分岐図のみ

def f(x, r):
    return 1+r*x+x**2

R=np.arange(-5, 5, 0.01)

for r in R:
    x=np.arange(-5, 5, 0.1)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.1.2
def f(x, r):
    return r-np.cosh(x)

R=np.arange(0, 10, 0.01)

for r in R:
    x=np.arange(-5, 5, 0.1)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.1.3
def f(x, r):
    return r+x-np.log(1+x)

R=np.arange(-2, 1, 0.01)

for r in R:
    x=np.arange(-0.99, 5, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.1.4

def f(x, r):
    x[x==-1]=None
    return r+x/2-x/(1+x)

R=np.arange(-2, 1, 0.01)

for r in R:
    x=np.arange(-0.99, 2, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.1.5 (a)

def f(x, r):
    return r**2-x**2

R=np.arange(-5, 5, 0.01)

for r in R:
    x=np.arange(-3, 3, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.1.5 (b)
#0になってくれないので1e-4以下はゼロとして扱うことで回避している

def f(x, r):
    return r**2+x**2

R=np.arange(-1, 1, 0.1)

for r in R:
    x=np.arange(-1, 1, 0.1)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=1e-5:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.2 トランスクリティカル分岐
#3.2.1

def f(x, r):
    return r*x+x**2

R=np.arange(-1, 1, 0.01)

for r in R:
    x=np.arange(-1, 1, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.2.2

def f(x, r):
    return r*x-np.log(1+x)

R=np.arange(0, 3, 0.01)

for r in R:
    x=np.arange(-0.99, 1, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.2.3

def f(x, r):
    return x-r*x*(1-x)

R=np.arange(0, 3, 0.01)

for r in R:
    x=np.arange(-0.99, 1, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.2.4

def f(x, r):
    return x*(r-np.exp(x))

R=np.arange(0, 3, 0.01)

for r in R:
    x=np.arange(-0.99, 1, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.3.2

k=0.01
L=np.arange(-3, 2, 0.01)
E=np.arange(0, 10, 0.01)

def f(E, k, l):
    return k*E*l*(1-E**2)/(1+l*E**2)

for l in L:
    E_d=f(E, k, l)

    i=0
    while i+1<E.shape[0]:
        if E_d[i]*E_d[i+1]<=0:
            tempE=E[i]+(E[i+1]-E[i])*E_d[i]/(E_d[i]-E_d[i+1])
            if E_d[i]>E_d[i+1]:
                plt.plot(l, tempE, marker='o', color='red', markersize=2)
            else:
                plt.plot(l, tempE, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('l')
plt.ylabel('E*')
plt.grid()
plt.show()

# %%
#3.4 ピッチフォーク分岐
#3.4.1 ベクトル場は省略し分岐図のみ

def f(x, r):
    return r*x+4*x**3

R=np.arange(-3, 3, 0.01)
x=np.arange(-5, 5, 0.01)

for r in R:
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.4.2

def f(x, r):
    return r*x-np.sinh(x)

R=np.arange(0, 3, 0.01)

for r in R:
    x=np.arange(-5, 5, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.4.3

def f(x, r):
    return r*x-4*x**3

R=np.arange(-2, 2, 0.01)

for r in R:
    x=np.arange(-5, 5, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.4.4

def f(x, r):
    return x+r*x/(1+x**2)

R=np.arange(-3, 1, 0.01)

for r in R:
    x=np.arange(-5, 5, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.4.5
#サドルノード分岐

def f(x, r):
    return r-3*x**2

R=np.arange(-2, 2, 0.01)

for r in R:
    x=np.arange(-5, 5, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.4.6
#トランスクリティカル分岐

def f(x, r):
    return r*x-x/(1+x)

R=np.arange(0, 3, 0.01)

for r in R:
    x=np.arange(-5, 5, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.4.7
#サドルノード分岐

def f(x, r):
    return 5-r*np.exp(-1*x**2)

R=np.arange(-10, 10, 0.01)

for r in R:
    x=np.arange(-5, 5, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.4.8
#トランスクリティカル分岐

def f(x, r):
    return r*x-x/(1+x)

R=np.arange(0, 5, 0.01)

for r in R:
    x=np.arange(-5, 5, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.4.9
#亜臨界ピッチフォーク分岐

def f(x, r):
    return x+np.tanh(r*x)

R=np.arange(-3, 3, 0.01)

for r in R:
    x=np.arange(-2, 2, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.4.10
#亜臨界ピッチフォーク分岐

def f(x, r):
    return r*x+x**3/(1+x**2)

R=np.arange(-2, 1, 0.01)

for r in R:
    x=np.arange(-5, 5, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.4.11(a)

def f(x, r):
    return r*x-np.sin(x)

r=0
x=np.arange(-10, 10, 0.1)
x_d=f(x, r)
plt.plot(x, x_d, linestyle='-', color='b', label='x_d')

i=0
fixpoint=[]
while i+1<x.shape[0]:
    if x_d[i]*x_d[i+1]<=0:
        fixpoint.append(x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1]))
        
    i+=1

fixpoint=np.array(fixpoint)

if fixpoint.shape[0]==0:
    xcenter=int(x.shape[0]/2)
    if f(x[xcenter], r)>0:
        plt.plot(xcenter, 0, marker='>', color='b')
    elif f(x[xcenter], r)<0:
        plt.plot(xcenter, 0, marker='<', color='b')
    else:
        pass
elif fixpoint.shape[0]==1:
    leftcenter=(fixpoint-x[0])/2
    if f(leftcenter, r)>0:
        plt.plot(leftcenter, 0, marker='>', color='b')
    elif f(leftcenter, r)<0:
        plt.plot(leftcenter, 0, marker='<', color='b')
    else:
        pass
else:
    #left side vector marker
    position=fixpoint[0]-(fixpoint[1]-fixpoint[0])/2
    if f(position, r)>0:
        plt.plot(position, 0, marker='>', color='b')
    else:
        plt.plot(position, 0, marker='<', color='b')
    
    #markers between fixpoints
    i=0
    while i+1<fixpoint.shape[0]:
        midpoint=(fixpoint[i]+fixpoint[i+1])/2
        if f(midpoint, r)>0:
            plt.plot(midpoint, 0, marker='>', color='b')
        else:
            plt.plot(midpoint, 0, marker='<', color='b')
        i+=1
    
    #right side vector marker
    position=fixpoint[-1]+(fixpoint[-1]-fixpoint[-2])/2
    if f(position, r)>0:
        plt.plot(position, 0, marker='>', color='b')
    else:
        plt.plot(position, 0, marker='<', color='b')
    
plt.legend()
plt.xlabel('x')
plt.grid()
plt.show()

# %%
#3.4.11(b)

def f(x, r):
    return r*x-np.sin(x)

r=2
x=np.arange(-10, 10, 0.1)
x_d=f(x, r)
plt.plot(x, x_d, linestyle='-', color='b', label='x_d')

i=0
fixpoint=[]
while i+1<x.shape[0]:
    if x_d[i]*x_d[i+1]<=0:
        fixpoint.append(x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1]))
        
    i+=1

fixpoint=np.array(fixpoint)

if fixpoint.size==0:
    xcenter=int((x[0]+x[-1])/2)
    if f(x[xcenter], r)>0:
        plt.plot(xcenter, 0, marker='>', color='b')
    elif f(x[xcenter], r)<0:
        plt.plot(xcenter, 0, marker='<', color='b')
    else:
        pass
elif fixpoint.size==1:
    #left side vector marker
    leftcenter=(fixpoint+x[0])/2
    if f(leftcenter, r)>0:
        plt.plot(leftcenter, 0, marker='>', color='b')
    elif f(leftcenter, r)<0:
        plt.plot(leftcenter, 0, marker='<', color='b')
    else:
        pass
    
    #right side vector marker
    rightcenter=(fixpoint+x[-1])/2
    if f(rightcenter, r)>0:
        plt.plot(rightcenter, 0, marker='>', color='b')
    elif f(rightcenter, r)<0:
        plt.plot(rightcenter, 0, marker='<', color='b')
    else:
        pass
else:
    #left side vector marker
    position=fixpoint[0]-(fixpoint[1]-fixpoint[0])/2
    if f(position, r)>0:
        plt.plot(position, 0, marker='>', color='b')
    else:
        plt.plot(position, 0, marker='<', color='b')
    
    #markers between fixpoints
    i=0
    while i+1<fixpoint.shape[0]:
        midpoint=(fixpoint[i]+fixpoint[i+1])/2
        if f(midpoint, r)>0:
            plt.plot(midpoint, 0, marker='>', color='b')
        else:
            plt.plot(midpoint, 0, marker='<', color='b')
        i+=1
    
    #right side vector marker
    position=fixpoint[-1]+(fixpoint[-1]-fixpoint[-2])/2
    if f(position, r)>0:
        plt.plot(position, 0, marker='>', color='b')
    else:
        plt.plot(position, 0, marker='<', color='b')
    
plt.legend()
plt.xlabel('x')
plt.grid()
plt.show()

# %%
#3.4.11(c)-(f)

def f(x, r):
    return r*x-np.sin(x)

R=np.arange(-0.5, 1.2, 0.01)
x=np.arange(-30, 30, 0.1)

for r in R:
    x_d=f(x, r)
    
    i=0
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)

        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.4.12
#4分岐

def f(x, r):
    return (r-x**2)*(2*r-x**2)

R=np.arange(-1, 5, 0.01)
x=np.arange(-5, 5, 0.01)

for r in R:
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.title('4-furcation')
plt.grid()
plt.show()

# %%
#3.4.12
#n分岐

def f(x, r, n):
    k=n%2
    n=int(n/2)
    temp=1
    
    for i in range(n):
        temp*=((i+1)*r-x**2)

    return temp*(x**k)

R=np.arange(-2, 2, 0.01)
x=np.arange(-2, 2, 0.01)
N=np.arange(5, 20, 1)

for n in N:
    for r in R:
        x_d=f(x, r, n)

        i=1
        while i+1<x.shape[0]:
            if x_d[i]*x_d[i+1]<=0:
                tempx=x[i]+(x[i+1]-x[i])*x_d[i]/(x_d[i]-x_d[i+1])
                if x_d[i]>x_d[i+1]:
                    plt.plot(r, tempx, marker='o', color='red', markersize=2)
                else:
                    plt.plot(r, tempx, marker='o', color='blue', markersize=2)
            i+=1

    plt.xlabel('r')
    plt.ylabel('x*')
    plt.title(str(n)+'-furcation')
    plt.grid()
    plt.show()

# %%
#3.4.13(a)

def f(x, r):
    return r-x-np.exp(-1*x)

def fd(x, r):
    return -1+np.exp(-1*x)

#for Newton-Raphson method
#In: position (x, y) and grad
#Out: x position where x axis crosses the line made by In position and grad
def NR(x, y, grad):
    return x-y/grad

R=np.arange(0.01, 3, 0.01)
NRtimes=10

for r in R:
    x=np.arange(-2, 2, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]
            for t in range(NRtimes):
                y=f(tempx, r)
                grad=fd(tempx, r)
                tempx=NR(tempx, y, grad)
                
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.4.13(b)

def f(x, r):
    return 1-x-np.exp(-1*r*x)

def fd(x, r):
    return -1+r*np.exp(-1*r*x)

#for Newton-Raphson method
#In: position (x, y) and grad
#Out: x position where x axis crosses the line made by In position and grad
def NR(x, y, grad):
    return x-y/grad

R=np.arange(0.01, 3, 0.01)
NRtimes=10

for r in R:
    x=np.arange(-2, 2, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]
            for t in range(NRtimes):
                y=f(tempx, r)
                grad=fd(tempx, r)
                tempx=NR(tempx, y, grad)
                
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.4.14(b)

def f(x, r):
    return r*x+x**3-x**5

def fd(x, r):
    return r+3*x**2-5*x**4

def NR(x, y, grad):
    return x-y/grad

R=np.arange(-3, 3, 0.01)
NRtimes=10

for r in R:
    x=np.arange(-2, 2, 0.01)
    x_d=f(x, r)

    i=1
    while i+1<x.shape[0]:
        if x_d[i]*x_d[i+1]<=0:
            tempx=x[i]
            for t in range(NRtimes):
                y=f(tempx, r)
                grad=fd(tempx, r)
                tempx=NR(tempx, y, grad)
                
            if x_d[i]>x_d[i+1]:
                plt.plot(r, tempx, marker='o', color='red', markersize=2)
            else:
                plt.plot(r, tempx, marker='o', color='blue', markersize=2)
        i+=1

plt.xlabel('r')
plt.ylabel('x*')
plt.grid()
plt.show()

# %%
#3.4.16(a)
def f(x, r):
    return x**4/4-r*x

X=np.arange(-5, 5, 0.01)
R=np.arange(-5, 5, 0.2)

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')

for r in R:
    V=f(X, r)
    ax.plot(np.ones(X.size)*r, X, V, color='b')

plt.grid()
plt.show()

# %%
#3.4.16(b)
def f(x, r):
    return x**3/3-r*x**2/2

X=np.arange(-5, 5, 0.01)
R=np.arange(-5, 5, 0.2)

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')

for r in R:
    V=f(X, r)
    ax.plot(np.ones(X.size)*r, X, V, color='b')

plt.grid()
plt.show()

# %%
#3.4.16(c)
def f(x, r):
    return x**6/6-x**4/4-r*x**2/2

X=np.arange(-2, 2, 0.01)
R=np.arange(-5, 5, 0.2)

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')

for r in R:
    V=f(X, r)
    ax.plot(np.ones(X.size)*r, X, V, color='b')

plt.grid()
plt.show()

# %%
#3.5.4(c) 考え中...

# %%
#3.6.2(a)
def f(x, r, h):
    return h+r*x-x**2

H=np.array([-1, 0, 1])
R=np.arange(-5, 5, 0.01)
X=np.arange(-5, 5, 0.1)

for h in H:
    for r in R:

        x_d=f(X, r, h)

        i=1
        while i+1<X.shape[0]:
            if x_d[i]*x_d[i+1]<=0:
                tempx=X[i]+(X[i+1]-X[i])*x_d[i]/(x_d[i]-x_d[i+1])
                if x_d[i]>x_d[i+1]:
                    plt.plot(r, tempx, marker='o', color='red', markersize=2)
                else:
                    plt.plot(r, tempx, marker='o', color='blue', markersize=2)
            i+=1

    plt.xlabel('r')
    plt.ylabel('x*')
    plt.grid()
    plt.title('h='+str(h))
    plt.show()

# %%
#3.6.2(c)考え中...
