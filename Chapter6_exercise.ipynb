# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#6.1.1
def f(x, y):
    return x-y

def g(x, y):
    return 1-np.exp(x)

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.arange(-2, 2, 0.1)
Y=np.arange(-2, 2, 0.1)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')

#固定点(x*, y*)=(0, 0)の安定性判定
fixpoint=np.array([0, 0])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# [0 0]: saddle

# %%
#6.1.2
def f(x, y):
    return x-x**3

def g(x, y):
    return -y

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.arange(-2, 2, 0.1)
Y=np.arange(-2, 2, 0.1)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')
        
#固定点(x*, y*)=(0, 0)の安定性判定
fixpoint=np.array([0, 0])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

#固定点(x*, y*)=(1, 0)の安定性判定
fixpoint=np.array([1, 0])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

#固定点(x*, y*)=(-1, 0)の安定性判定
fixpoint=np.array([-1, 0])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# [0 0]: saddle
# [1 0]: stable spiral
# [-1  0]: stable spiral

# %%
#6.1.3
def f(x, y):
    return x*(x-y)

def g(x, y):
    return y*(2*x-y)

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.arange(-2, 2, 0.05)
Y=np.arange(-2, 2, 0.05)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')
        
#固定点(x*, y*)=(0, 0)の安定性判定
fixpoint=np.array([0, 0])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# Check

# %%
#6.1.4
def f(x, y):
    return y

def g(x, y):
    return x*(1+y)-1

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.arange(-2, 2, 0.1)
Y=np.arange(-2, 2, 0.1)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')
        
#固定点(x*, y*)=(1, 0)の安定性判定
fixpoint=np.array([1, 0])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# [1 0]: saddle

# %%
#6.1.5
def f(x, y):
    return x*(2-x-y)

def g(x, y):
    return x-y

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.arange(-2, 2, 0.1)
Y=np.arange(-2, 2, 0.1)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')
        
#固定点(x*, y*)=(0, 0)の安定性判定
fixpoint=np.array([0, 0])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

#固定点(x*, y*)=(1, 1)の安定性判定
fixpoint=np.array([1, 1])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# [0 0]: saddle
# [1 1]: stable node

# %%
#6.1.6
def f(x, y):
    return x**2-y

def g(x, y):
    return x-y

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.arange(-2, 2, 0.1)
Y=np.arange(-2, 2, 0.1)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')
        
#固定点(x*, y*)=(0, 0)の安定性判定
fixpoint=np.array([0, 0])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

#固定点(x*, y*)=(1, 1)の安定性判定
fixpoint=np.array([1, 1])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# [0 0]: stable node
# [1 1]: saddle

# %%
#6.1.8
def f(x, y):
    return y

def g(x, y):
    return -x+y*(1-x**2)

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.arange(-2, 2, 0.1)
Y=np.arange(-2, 2, 0.1)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')
        
#固定点(x*, y*)=(0, 0)の安定性判定
fixpoint=np.array([0, 0])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# [0 0]: unstable spiral

# %%
#6.1.9
def f(x, y):
    return 2*x*y

def g(x, y):
    return y**2-x**2

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.arange(-2, 2, 0.1)
Y=np.arange(-2, 2, 0.1)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')
        
#固定点(x*, y*)=(0, 0)の安定性判定
fixpoint=np.array([0, 0])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# Check

# %%
#6.1.10
def f(x, y):
    return y+y**2

def g(x, y):
    return -x/2+y/5-x*y+6*y**2/5

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.arange(-3, 1, 0.1)
Y=np.arange(-2, 1, 0.1)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')
        
#固定点(x*, y*)=(0, 0)の安定性判定
fixpoint=np.array([0, 0])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

#固定点(x*, y*)=(-2, -1)の安定性判定
fixpoint=np.array([-2, -1])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-3, 1)
plt.ylim(-2, 1)
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# [0 0]: unstable spiral
# [-2 -1]: stable node

# %%
#6.1.11
def f(x, y):
    return y+y**2

def g(x, y):
    return -x+y/5-x*y+6*y**2/5

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.arange(-1, 1, 0.1)
Y=np.arange(-1, 1, 0.1)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')
        
#固定点(x*, y*)=(0, 0)の安定性判定
fixpoint=np.array([0, 0])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# [0 0]: unstable spiral

# %%
#6.3.1
def f(x, y):
    return x-y

def g(x, y):
    return x**2-4

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.linspace(-3, 3, 61)
Y=np.linspace(-3, 3, 61)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')
        
#固定点(x*, y*)=(2, 2)の安定性判定
fixpoint=np.array([2, 2])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')
    
#固定点(x*, y*)=(-2, -2)の安定性判定
fixpoint=np.array([-2, -2])
J=np.array([
    [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
    [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
])

tau=J[0, 0]+J[1, 1]
D=np.linalg.det(J)

if D>0:
    if tau==0:
        print(str(fixpoint)+': center')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
    elif tau>0:
        if tau**2-4*D>0:
            print(str(fixpoint)+': unstable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
        else:
            print(str(fixpoint)+': unstable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
    else:
        #tau<0
        if tau**2-4*D<0:
            print(str(fixpoint)+': stable node')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
        else:
            print(str(fixpoint)+': stable spiral')
            plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
elif D<0:
    print(str(fixpoint)+': saddle')
    plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
else:
    print('Check')
    plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-3, 3)
plt.ylim(-3, 3)
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# [2 2]: unstable spiral
# [-2 -2]: saddle

# %%
#6.3.2
pi=np.pi

def f(x, y):
    return np.sin(y)

def g(x, y):
    return x-x**3

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.linspace(-2, 2, 73)
Y=np.linspace(-1.5*pi, 1.5*pi, 73)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')
    
#固定点の安定性判定
Fixpoints=np.array([
    [0, -pi],
    [0, 0],
    [0, pi],
    [1, -pi],
    [1, 0],
    [1, pi],
    [-1, -pi],
    [-1, 0],
    [-1, pi]
])

for i in range(Fixpoints.shape[0]):
    fixpoint=Fixpoints[i]
    J=np.array([
        [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
        [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
    ])

    tau=J[0, 0]+J[1, 1]
    D=np.linalg.det(J)

    if D>0:
        if tau==0:
            print(str(fixpoint)+': center')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
        elif tau>0:
            if tau**2-4*D>0:
                print(str(fixpoint)+': unstable node')
                plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
            else:
                print(str(fixpoint)+': unstable spiral')
                plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
        else:
            #tau<0
            if tau**2-4*D<0:
                print(str(fixpoint)+': stable node')
                plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
            else:
                print(str(fixpoint)+': stable spiral')
                plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
    elif D<0:
        print(str(fixpoint)+': saddle')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
    else:
        print('Check')
        plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-2, 2)
plt.ylim(-1.5*pi, 1.5*pi)
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# [ 0.         -3.14159265]: center
# [0. 0.]: saddle
# [0.         3.14159265]: center
# [ 1.         -3.14159265]: saddle
# [1. 0.]: center
# [1.         3.14159265]: saddle
# [-1.         -3.14159265]: saddle
# [-1.  0.]: center
# [-1.          3.14159265]: saddle

# %%
#6.3.3

def f(x, y):
    return 1+y-np.exp(-x)

def g(x, y):
    return x**3-y

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.linspace(-1, 1, 41)
Y=np.linspace(-1, 1, 41)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')
    
#固定点の安定性判定
Fixpoints=np.array([
    [0, 0],
])

for i in range(Fixpoints.shape[0]):
    fixpoint=Fixpoints[i]
    J=np.array([
        [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
        [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
    ])

    tau=J[0, 0]+J[1, 1]
    D=np.linalg.det(J)

    if D>0:
        if tau==0:
            print(str(fixpoint)+': center')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
        elif tau>0:
            if tau**2-4*D>0:
                print(str(fixpoint)+': unstable node')
                plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
            else:
                print(str(fixpoint)+': unstable spiral')
                plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
        else:
            #tau<0
            if tau**2-4*D<0:
                print(str(fixpoint)+': stable node')
                plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
            else:
                print(str(fixpoint)+': stable spiral')
                plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
    elif D<0:
        print(str(fixpoint)+': saddle')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
    else:
        print('Check')
        plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# [0 0]: saddle

# %%
#6.3.4

def f(x, y):
    return y+x-x**3

def g(x, y):
    return -y

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.linspace(-1.5, 1.5, 31)
Y=np.linspace(-1, 1, 21)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')
    
#固定点の安定性判定
Fixpoints=np.array([
    [-1, 0],
    [0, 0],
    [1, 0]
])

for i in range(Fixpoints.shape[0]):
    fixpoint=Fixpoints[i]
    J=np.array([
        [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
        [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
    ])

    tau=J[0, 0]+J[1, 1]
    D=np.linalg.det(J)

    if D>0:
        if tau==0:
            print(str(fixpoint)+': center')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
        elif tau>0:
            if tau**2-4*D>0:
                print(str(fixpoint)+': unstable node')
                plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
            else:
                print(str(fixpoint)+': unstable spiral')
                plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
        else:
            #tau<0
            if tau**2-4*D<0:
                print(str(fixpoint)+': stable node')
                plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
            else:
                print(str(fixpoint)+': stable spiral')
                plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
    elif D<0:
        print(str(fixpoint)+': saddle')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
    else:
        print('Check')
        plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-1.5, 1.5)
plt.ylim(-1, 1)
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# [-1  0]: stable spiral
# [0 0]: saddle
# [1 0]: stable spiral

# %%
#6.3.5
pi=np.pi

def f(x, y):
    return np.sin(y)

def g(x, y):
    return np.cos(x)

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.linspace(-pi*(7/6), pi*(7/6), 29)
Y=np.linspace(-pi*(7/6), pi*(7/6), 29)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')
    
#固定点の安定性判定
Fixpoints=np.array([
    [-pi/2, -pi],
    [-pi/2, 0],
    [-pi/2, pi],
    [pi/2, -pi],
    [pi/2, 0],
    [pi/2, pi]
])

for i in range(Fixpoints.shape[0]):
    fixpoint=Fixpoints[i]
    J=np.array([
        [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
        [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
    ])

    tau=J[0, 0]+J[1, 1]
    D=np.linalg.det(J)

    if D>0:
        if tau==0:
            print(str(fixpoint)+': center')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
        elif tau>0:
            if tau**2-4*D>0:
                print(str(fixpoint)+': unstable node')
                plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
            else:
                print(str(fixpoint)+': unstable spiral')
                plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
        else:
            #tau<0
            if tau**2-4*D<0:
                print(str(fixpoint)+': stable node')
                plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
            else:
                print(str(fixpoint)+': stable spiral')
                plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
    elif D<0:
        print(str(fixpoint)+': saddle')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
    else:
        print('Check')
        plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-pi*(7/6), pi*(7/6))
plt.ylim(-pi*(7/6), pi*(7/6))
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# [-1.57079633 -3.14159265]: center
# [-1.57079633  0.        ]: saddle
# [-1.57079633  3.14159265]: center
# [ 1.57079633 -3.14159265]: saddle
# [1.57079633 0.        ]: center
# [1.57079633 3.14159265]: saddle

# %%
#6.3.6

def f(x, y):
    return x*y-1

def g(x, y):
    return x-y**3

def dfdx(x, y):
    delta=1e-4
    return (f(x+delta, y)-f(x-delta, y))/(2*delta)

def dfdy(x, y):
    delta=1e-4
    return (f(x, y+delta)-f(x, y-delta))/(2*delta)

def dgdx(x, y):
    delta=1e-4
    return (g(x+delta, y)-g(x-delta, y))/(2*delta)

def dgdy(x, y):
    delta=1e-4
    return (g(x, y+delta)-g(x, y-delta))/(2*delta)

X=np.linspace(-2, 2, 21)
Y=np.linspace(-2, 2, 21)
X, Y=np.meshgrid(X, Y)

#ベクトル場の描出
plt.quiver(X, Y, f(X, Y), g(X, Y))

#ヌルクラインの描出
plt.contour(X, Y, f(X, Y), levels=[0], colors='green')
plt.contour(X, Y, g(X, Y), levels=[0], colors='orange')
    
#固定点の安定性判定
Fixpoints=np.array([
    [1, 1],
    [-1, -1]
])

for i in range(Fixpoints.shape[0]):
    fixpoint=Fixpoints[i]
    J=np.array([
        [dfdx(fixpoint[0], fixpoint[1]), dfdy(fixpoint[0], fixpoint[1])],
        [dgdx(fixpoint[0], fixpoint[1]), dgdy(fixpoint[0], fixpoint[1])]
    ])

    tau=J[0, 0]+J[1, 1]
    D=np.linalg.det(J)

    if D>0:
        if tau==0:
            print(str(fixpoint)+': center')
            plt.plot(fixpoint[0], fixpoint[1], marker='o', color='green')
        elif tau>0:
            if tau**2-4*D>0:
                print(str(fixpoint)+': unstable node')
                plt.plot(fixpoint[0], fixpoint[1], marker='o', color='blue')
            else:
                print(str(fixpoint)+': unstable spiral')
                plt.plot(fixpoint[0], fixpoint[1], marker='s', color='blue')
        else:
            #tau<0
            if tau**2-4*D<0:
                print(str(fixpoint)+': stable node')
                plt.plot(fixpoint[0], fixpoint[1], marker='o', color='red')
            else:
                print(str(fixpoint)+': stable spiral')
                plt.plot(fixpoint[0], fixpoint[1], marker='s', color='red')
    elif D<0:
        print(str(fixpoint)+': saddle')
        plt.plot(fixpoint[0], fixpoint[1], marker='o', color='magenta')
    else:
        print('Check')
        plt.plot(fixpoint[0], fixpoint[1], marker='*', color='magenta')

plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('vector field')
plt.grid()
plt.show()
# Out:
# [1 1]: saddle
# [-1 -1]: stable spiral
